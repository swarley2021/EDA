# %% [markdown]
# <a href="https://colab.research.google.com/github/swarley2021/EDA/blob/projectt/22BDS0258.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 22BDS0258

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Medicaid1986.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    rownames  visits  exposure  children  age  income  health1  health2  \
# 0         1       0       100         1   24  14.500    0.495   -0.854
# 1         2       1        90         3   19   6.000    0.520   -0.969
# 2         3       0       106         4   17   8.377   -1.227    0.317
# 3         4       0       114         2   29   6.000   -1.524    0.457
# 4         5      11       115         1   26   8.500    0.173   -0.599
#
#    access married  gender ethnicity  school enroll program
# 0    0.50      no  female      cauc      13    yes    afdc
# 1    0.17      no  female      cauc      11    yes    afdc
# 2    0.42      no  female      cauc      12    yes    afdc
# 3    0.33      no  female      cauc      12    yes    afdc
# 4    0.67      no  female      cauc      16    yes    afdc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# # DIMENSIONS

# %%
rows, cols = df.shape

print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
# Out:
# Number of rows: 996
# Number of columns: 15

# %% [markdown]
# # summary statistics

# %%
print("Shape of dataset:", df.shape)
print("\nColumn names:\n", df.columns.tolist())
print("\nData types:\n", df.dtypes)
print("\nFirst 5 rows:\n", df.head())
print("\nSummary Statistics:\n", df.describe(include="all"))
# Out:
# Shape of dataset: (996, 15)
#
# Column names:
#  ['rownames', 'visits', 'exposure', 'children', 'age', 'income', 'health1', 'health2', 'access', 'married', 'gender', 'ethnicity', 'school', 'enroll', 'program']
#
# Data types:
#  rownames       int64
# visits         int64
# exposure       int64
# children       int64
# age            int64
# income       float64
# health1      float64
# health2      float64
# access       float64
# married       object
# gender        object
# ethnicity     object
# school         int64
# enroll        object
# program       object
# dtype: object
#
# First 5 rows:
#     rownames  visits  exposure  children  age  income  health1  health2  \
# 0         1       0       100         1   24  14.500    0.495   -0.854
# 1         2       1        90         3   19   6.000    0.520   -0.969
# 2         3       0       106         4   17   8.377   -1.227    0.317
# 3         4       0       114         2   29   6.000   -1.524    0.457
# 4         5      11       115         1   26   8.500    0.173   -0.599
#
#    access married  gender ethnicity  school enroll program
# 0    0.50      no  female      cauc      13    yes    afdc
# 1    0.17      no  female      cauc      11    yes    afdc
# 2    0.42      no  female      cauc      12    yes    afdc
# 3    0.33      no  female      cauc      12    yes    afdc
# 4    0.67      no  female      cauc      16    yes    afdc
#
# Summary Statistics:
#            rownames      visits    exposure    children         age  \
# count   996.000000  996.000000  996.000000  996.000000  996.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean    498.500000    1.930723  104.060241    1.314257   55.205823
# std     287.664735    3.354472    9.144973    1.509314   24.961373
# min       1.000000    0.000000   32.000000    0.000000   16.000000
# 25%     249.750000    0.000000   98.000000    0.000000   29.000000
# 50%     498.500000    1.000000  104.000000    1.000000   66.000000
# 75%     747.250000    3.000000  111.000000    2.000000   78.000000
# max     996.000000   50.000000  120.000000    9.000000  105.000000
#
#             income     health1     health2      access married  gender  \
# count   996.000000  996.000000  996.000000  996.000000     996     996
# unique         NaN         NaN         NaN         NaN       2       2
# top            NaN         NaN         NaN         NaN      no  female
# freq           NaN         NaN         NaN         NaN     780     843
# mean      8.191302   -0.000013    0.000020    0.398102     NaN     NaN
# std       3.630549    1.436934    0.740226    0.184439     NaN     NaN
# min       0.500000   -2.264000   -2.177000    0.000000     NaN     NaN
# 25%       6.000000   -1.151250   -0.472000    0.297500     NaN     NaN
# 50%       7.990000   -0.316500   -0.009000    0.420000     NaN     NaN
# 75%       8.500000    0.858000    0.347000    0.500000     NaN     NaN
# max      17.500000    7.217000    3.048000    1.000000     NaN     NaN
#
#        ethnicity      school enroll program
# count        996  996.000000    996     996
# unique         2         NaN      2       2
# top         cauc         NaN     no     ssi
# freq         691         NaN    506     511
# mean         NaN    9.029116    NaN     NaN
# std          NaN    4.353957    NaN     NaN
# min          NaN    0.000000    NaN     NaN
# 25%          NaN    6.000000    NaN     NaN
# 50%          NaN   10.000000    NaN     NaN
# 75%          NaN   12.000000    NaN     NaN
# max          NaN   18.000000    NaN     NaN
