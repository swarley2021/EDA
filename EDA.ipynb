# %% [markdown]
# <a href="https://colab.research.google.com/github/swarley2021/EDA/blob/projectt/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("EDA PROJECT")
# Out:
# EDA PROJECT
